# %%
from Test_task import MyPlot
from IPython.display import Image
aim_file = 'https://ai-process-sandy.s3.eu-west-1.amazonaws.com/purge/deviation.json'
plotter = MyPlot('plots')
plot_paths = plotter.draw_plots(aim_file)

for path in plot_paths:
    display(Image(filename=path))
# Out:
# ['plots\\corner_accuracy.png', 'plots\\mean_deviation.png', 'plots\\min_deviation.png', 'plots\\max_deviation.png', 'plots\\mean_min_max.png']
